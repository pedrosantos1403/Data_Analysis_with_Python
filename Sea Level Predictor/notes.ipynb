# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')

# %%
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], label='original data')
plt.show()

# %%
best = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])

# %%
future_years = np.arange(2014,2051)
years = np.concatenate([df['Year'], future_years])
years
# Out:
# array([1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890,
#        1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901,
#        1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#        1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#        1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
#        1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033,
#        2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044,
#        2045, 2046, 2047, 2048, 2049, 2050], dtype=int64)

# %%
# Ploting first line
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], label='original data')
plt.plot(years, best.intercept + best.slope*years, label='best fit', color='r')
plt.legend()
plt.show()

# %%
# Calculating second line of best fit (2000 - 2050)
best_second = linregress(df.iloc[120:]['Year'], df.iloc[120:]['CSIRO Adjusted Sea Level'])

# %%
# Creating array with years from 2000 to 2050
years_second = np.arange(2000, 2051)
years_second
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032,
#        2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043,
#        2044, 2045, 2046, 2047, 2048, 2049, 2050])

# %%
# Ploting second line
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], label='original data')
plt.plot(years, best.intercept + best.slope*years, label='best fit (all)', color='r')
plt.plot(years_second, best_second.intercept + best_second.slope*years_second, label='best fit (2000)', color='g')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
plt.legend()
plt.show()
